# %% [markdown]
# <span style="
#   background: linear-gradient(90deg, #FF5733, #33FF57, #3357FF);
#   -webkit-background-clip: text;
#   -webkit-text-fill-color: transparent;
#   font-size: 48px;
#   font-weight: bold;
#   text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#   transition: transform 0.3s ease;
#   display: inline-block;
# " onmouseover="this.style.transform='scale(1.05)'" onmouseout="this.style.transform='scale(1)'">
#   Color Palette Estimation
# </span>

# %%
# Importing necessary libraries
from image_color_extraction import ImageColorExtractor, visualize_colors
from PIL import Image
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import io
import numpy as np

# %%
image_color_extractor = ImageColorExtractor(each_channels_possible_values=8)

# %%
visualize_colors(image_color_extractor.basic_colors)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# <span style="
#   background: linear-gradient(90deg, #FF5733, #33FF57, #3357FF);
#   -webkit-background-clip: text;
#   -webkit-text-fill-color: transparent;
#   font-size: 48px;
#   font-weight: bold;
#   text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);
#   transition: transform 0.3s ease;
#   display: inline-block;
# " onmouseover="this.style.transform='scale(1.05)'" onmouseout="this.style.transform='scale(1)'">
#   Image
# </span>

# %%
image = Image.open("test_images/maksim-istomin-_eaTMHXVsYY-unsplash.jpg")
max_image_size = 1280
image.thumbnail((max_image_size, max_image_size), Image.Resampling.LANCZOS)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
extracted_colors = image_color_extractor(image, max_num_colors=16)
print(f"Num extracted colors: {len(extracted_colors)}")
# Out:
# Num extracted colors: 16

# %%
visualized_colors = visualize_colors(extracted_colors)
visualized_colors
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# <span style="
#   background: linear-gradient(90deg, #FF5733, #33FF57, #3357FF);
#   -webkit-background-clip: text;
#   -webkit-text-fill-color: transparent;
#   font-size: 56px;
#   font-weight: bold;
#   text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.4), 0 0 25px rgba(255, 87, 51, 0.6);
#   transition: transform 0.3s ease, text-shadow 0.3s ease;
#   display: inline-block;
# " onmouseover="this.style.transform='scale(1.1)'; this.style.textShadow='4px 4px 8px rgba(0, 0, 0, 0.5), 0 0 30px rgba(255, 87, 51, 0.8)'" onmouseout="this.style.transform='scale(1)'; this.style.textShadow='3px 3px 6px rgba(0, 0, 0, 0.4), 0 0 25px rgba(255, 87, 51, 0.6)'">
#   HEX
# </span>

# %%
# Converting extracted RGB colors to hexadecimal format for easier representation, storing them in a list.
def rgb_to_hex(r, g, b):
    return "#" + ("{:02X}" * 3).format(r, g, b)


hex_colors = []
for color in extracted_colors:
    hex_colors.append(rgb_to_hex(*np.floor(color * 255).astype(np.uint8).tolist()))
# uint8_colors = pd.DataFrame(uint8_colors, columns=["R", "G", "B"])
# uint8_colors
hex_colors
# Out:
# ['#0F1114',
#  '#3F120E',
#  '#1E3444',
#  '#403938',
#  '#663931',
#  '#82370C',
#  '#625D5D',
#  '#A25A34',
#  '#C85B13',
#  '#986858',
#  '#EF7B0A',
#  '#D6883F',
#  '#F3A720',
#  '#EFC055',
#  '#F9DE8B',
#  '#FDF8D9']
